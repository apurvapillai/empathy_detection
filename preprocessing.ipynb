# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Step 1: Load the dataset
train_file = 'empatheticdialogues/train.csv'
val_file = 'empatheticdialogues/valid.csv'
test_file = 'empatheticdialogues/test.csv'

train_df = pd.read_csv(train_file, on_bad_lines='skip')
val_df = pd.read_csv(val_file, on_bad_lines='skip')
test_df = pd.read_csv(test_file, on_bad_lines='skip')

non_standard_indices = [2355, 36628, 49433, 56957, 65019]
train_df = train_df.drop(index=non_standard_indices)
train_df.shape
# Out:
# (76663, 8)

# %%
train_df['tags'].unique()
# Out:
# array([nan, '<HI>', '<HI> <UNIGRAM>', '<UNIGRAM>', '<POLITICAL>',
#        '<UNIGRAM> <NUMERAL>', '<IRREGULAR_COLON_FORMAT>'], dtype=object)

# %%
train_df.fillna(0, inplace=True)

# %%
print(f'Cleaned DataFrame shape: {train_df.shape}')
# Out:
# Cleaned DataFrame shape: (76663, 8)

# %%
train_df['tags'] = 0

# %%
# Save the cleaned dataset to a new CSV file
train_df.to_csv('cleaned_empathetic_dialogues.csv', index=False)

# %%
train_df['selfeval'].dtype
# Out:
# dtype('O')

# %%
selfeval_split = train_df['selfeval'].str.split('|', expand=True)
selfeval_split
# Out:
#        0  1    2  3  4
# 0      5  5  5_2  2  5
# 1      5  5  5_2  2  5
# 2      5  5  5_2  2  5
# 3      5  5  5_2  2  5
# 4      5  5  5_2  2  5
# ...   .. ..  ... .. ..
# 76663  5  5  5_5  5  5
# 76664  5  5  5_5  5  5
# 76665  5  5  5_5  5  5
# 76666  5  5  5_5  5  5
# 76667  5  5  5_5  5  5
#
# [76663 rows x 5 columns]

# %%
CD_split = selfeval_split[2].str.split('_', expand=True)
CD_split
# Out:
#        0  1
# 0      5  2
# 1      5  2
# 2      5  2
# 3      5  2
# 4      5  2
# ...   .. ..
# 76663  5  5
# 76664  5  5
# 76665  5  5
# 76666  5  5
# 76667  5  5
#
# [76663 rows x 2 columns]

# %%
selfeval_final = pd.DataFrame({
    'A': selfeval_split[0],
    'B': selfeval_split[1],
    'C': CD_split[0],
    'D': CD_split[1],
    'E': selfeval_split[3],
    'F': selfeval_split[4]
})

# %%
selfeval_final
# Out:
#        A  B  C  D  E  F
# 0      5  5  5  2  2  5
# 1      5  5  5  2  2  5
# 2      5  5  5  2  2  5
# 3      5  5  5  2  2  5
# 4      5  5  5  2  2  5
# ...   .. .. .. .. .. ..
# 76663  5  5  5  5  5  5
# 76664  5  5  5  5  5  5
# 76665  5  5  5  5  5  5
# 76666  5  5  5  5  5  5
# 76667  5  5  5  5  5  5
#
# [76663 rows x 6 columns]

# %%
# Step 4: Convert the new columns to numeric (if needed)
selfeval_final = selfeval_final.apply(pd.to_numeric, errors='coerce')

# %%
train_df = pd.concat([train_df, selfeval_final], axis=1)
# Step 6: Remove duplicate columns
train_df = train_df.loc[:, ~train_df.columns.duplicated()]

# Display the DataFrame with the new columns
print("\nDataFrame with separated 'selfeval' values (duplicates removed):")
print(train_df[['selfeval', 'A', 'B', 'C', 'D', 'E', 'F']].head())
# Out:
# DataFrame with separated 'selfeval' values (duplicates removed):
#       selfeval    A    B    C    D    E    F
# 0  5|5|5_2|2|5  5.0  5.0  5.0  2.0  2.0  5.0
# 1  5|5|5_2|2|5  5.0  5.0  5.0  2.0  2.0  5.0
# 2  5|5|5_2|2|5  5.0  5.0  5.0  2.0  2.0  5.0
# 3  5|5|5_2|2|5  5.0  5.0  5.0  2.0  2.0  5.0
# 4  5|5|5_2|2|5  5.0  5.0  5.0  2.0  2.0  5.0

# %%
train_df
# Out:
#                     conv_id  utterance_idx      context  \
# 0              hit:0_conv:1              1  sentimental
# 1              hit:0_conv:1              2  sentimental
# 2              hit:0_conv:1              3  sentimental
# 3              hit:0_conv:1              4  sentimental
# 4              hit:0_conv:1              5  sentimental
# ...                     ...            ...          ...
# 76663  hit:12424_conv:24848              5  sentimental
# 76664  hit:12424_conv:24849              1    surprised
# 76665  hit:12424_conv:24849              2    surprised
# 76666  hit:12424_conv:24849              3    surprised
# 76667  hit:12424_conv:24849              4    surprised
#
#                                                   prompt  speaker_idx  \
# 0      I remember going to the fireworks with my best...            1
# 1      I remember going to the fireworks with my best...            0
# 2      I remember going to the fireworks with my best...            1
# 3      I remember going to the fireworks with my best...            0
# 4      I remember going to the fireworks with my best...            1
# ...                                                  ...          ...
# 76663  I found some pictures of my grandma in the att...          389
# 76664  I woke up this morning to my wife telling me s...          294
# 76665  I woke up this morning to my wife telling me s...          389
# 76666  I woke up this morning to my wife telling me s...          294
# 76667  I woke up this morning to my wife telling me s...          389
#
#                                                utterance     selfeval  tags  \
# 0      I remember going to see the fireworks with my ...  5|5|5_2|2|5     0
# 1      Was this a friend you were in love with_comma_...  5|5|5_2|2|5     0
# 2                    This was a best friend. I miss her.  5|5|5_2|2|5     0
# 3                                    Where has she gone?  5|5|5_2|2|5     0
# 4                                     We no longer talk.  5|5|5_2|2|5     0
# ...                                                  ...          ...   ...
# 76663  Yeah reminds me of the good old days.  I miss ...  5|5|5_5|5|5     0
# 76664  I woke up this morning to my wife telling me s...  5|5|5_5|5|5     0
# 76665     Oh hey that's awesome!  That is awesome right?  5|5|5_5|5|5     0
# 76666  It is soooo awesome.  We have been wanting a b...  5|5|5_5|5|5     0
# 76667               That is awesome!!!! Congratulations!  5|5|5_5|5|5     0
#
#          A    B    C    D    E    F
# 0      5.0  5.0  5.0  2.0  2.0  5.0
# 1      5.0  5.0  5.0  2.0  2.0  5.0
# 2      5.0  5.0  5.0  2.0  2.0  5.0
# 3      5.0  5.0  5.0  2.0  2.0  5.0
# 4      5.0  5.0  5.0  2.0  2.0  5.0
# ...    ...  ...  ...  ...  ...  ...
# 76663  5.0  5.0  5.0  5.0  5.0  5.0
# 76664  5.0  5.0  5.0  5.0  5.0  5.0
# 76665  5.0  5.0  5.0  5.0  5.0  5.0
# 76666  5.0  5.0  5.0  5.0  5.0  5.0
# 76667  5.0  5.0  5.0  5.0  5.0  5.0
#
# [76663 rows x 14 columns]

# %%
# Optionally, save the updated DataFrame to a new CSV file
train_df.to_csv('updated_empathetic_dialogues.csv', index=False)

# %%
unique_tags = train_df['tags'].unique()
print(unique_tags)
# Out:
# [0]
